# %% [markdown]
# # 02 — Preprocessamento de Texto
#
# Demonstração e aplicação do pipeline de preprocessamento sobre o dataset B2W.
#
# **Etapas:**
# 1. Limpeza de texto (lowercase, URLs, pontuação, números)
# 2. Remoção de stopwords (NLTK PT)
# 3. Stemming (RSLP)
# 4. Lematização (spaCy — demonstrativo)
# 5. Aplicação ao dataset completo

# %%
import sys
sys.path.insert(0, "..")

import pandas as pd
from tqdm.auto import tqdm

from src.config import TEXT_COLUMN, PROCESSED_DIR
from src.data_loader import carregar_splits
from src.preprocessing import (
    limpar_texto,
    remover_stopwords,
    aplicar_stemming,
    aplicar_lematizacao,
    preprocessar_para_svm,
    preprocessar_para_embeddings,
)
from src.utils import set_seed, timer

set_seed()
tqdm.pandas()

# %% [markdown]
# ## 1. Carregar Splits

# %%
df_train, df_val, df_test = carregar_splits()
df_train.head(3)
# Out:
# Splits carregados: treino=90,368 | val=19,365 | teste=19,365
#        submission_date                                        reviewer_id  \
# 0  2018-01-01 09:59:57  1e926b3472c7e45c4102eafdce65be07f7dac5d0105c7d...
# 1  2018-01-16 06:51:53  bb764dae5ddf9f5a795715976d077eb1222919f93a278e...
# 2  2018-04-26 07:39:08  d11bd8ec2271d0f374c5137502ec041a0701f5ee2fbad3...
#
#   product_id                                       product_name product_brand  \
# 0   27798113  Quarto Infantil com Guarda Roupa 3 Portas, Côm...          None
# 1   14171433  Lanterna De Cabeca Tatica Cree Led Com Foco Aj...          None
# 2  132918761         Conjunto de Refratários Marinex - 10 Peças          None
#
#        site_category_lv1               site_category_lv2  \
# 0                 Móveis                 Quarto Completo
# 1        Esporte e Lazer                         Camping
# 2  Utilidades Domésticas  Bandejas, Assadeiras e Réchaud
#
#               review_title  overall_rating recommend_to_a_friend  \
# 0                     None               5                   Yes
# 1  Nao e o que eu esperava               2                    No
# 2                 Pratico:               5                   Yes
#
#                                          review_text  reviewer_birth_year  \
# 0  Gostei muito dos produtos, guarda roupa grande...               1968.0
# 1  A propaganda informava alcance de ate 250mts. ...               1947.0
# 2  Eu amei , era exatamente o que eu esperava ,  ...               1967.0
#
#   reviewer_gender reviewer_state sentimento  label  num_chars  num_words
# 0               F             RJ   positivo      2        295         50
# 1               M             SP   negativo      0         72         13
# 2               F             GO   positivo      2         67         13

# %% [markdown]
# ## 2. Demonstração das Etapas (Antes/Depois)

# %%
# Selecionar exemplos representativos (1 por classe)
exemplos = (
    df_train.groupby("sentimento")
    .sample(1, random_state=42)
    .reset_index(drop=True)
)

for _, row in exemplos.iterrows():
    texto = row[TEXT_COLUMN]
    print(f"=== {row['sentimento'].upper()} ===")
    print(f"Original:     {texto[:200]}..." if len(str(texto)) > 200 else f"Original:     {texto}")
    print(f"Limpo:        {limpar_texto(texto)[:200]}")
    print(f"Sem stopwords:{remover_stopwords(limpar_texto(texto))[:200]}")
    print(f"Com stemming: {aplicar_stemming(remover_stopwords(limpar_texto(texto)))[:200]}")
    print(f"Pipeline SVM: {preprocessar_para_svm(texto)[:200]}")
    print()
# Out:
# === NEGATIVO ===
# Original:     Fonte minuscula não dá para ler, a não ser que você use um telescópio, esperdicei meu dinheiro.
# Limpo:        fonte minuscula não dá para ler a não ser que você use um telescópio esperdicei meu dinheiro
# Sem stopwords:fonte minuscula dá ler use telescópio esperdicei dinheiro
# Com stemming: font minuscul dá ler use telescópi esperdic dinh
# Pipeline SVM: font minuscul dá ler use telescópi esperdic dinh
#
# === NEUTRO ===
# Original:     Não é exatamente como aparece na foto. Não sai todo pelo de uma só vez. Mas sai bastante excesso de pelo e os gatos gostam das cerdas quando passa neles.
# Limpo:        não é exatamente como aparece na foto não sai todo pelo de uma só vez mas sai bastante excesso de pelo e os gatos gostam das cerdas quando passa neles
# Sem stopwords:exatamente aparece foto sai todo vez sai bastante excesso gatos gostam cerdas passa neles
# Com stemming: exat aparec fot sai tod vez sai bast excess gat gost cerd pass nel
# Pipeline SVM: exat aparec fot sai tod vez sai bast excess gat gost cerd pass nel
#
# === POSITIVO ===
# Original:     tinha uma e dei pro meu irmão. caixa e ótimo valor e bem ver´stil som alto e que dá pra levar pra todo lugar gosto bastante. estou comprando outra agora pq sei que é boa.
# Limpo:        tinha uma e dei pro meu irmão caixa e ótimo valor e bem ver stil som alto e que dá pra levar pra todo lugar gosto bastante estou comprando outra agora pq sei que é boa
# Sem stopwords:dei pro irmão caixa ótimo valor bem ver stil som alto dá pra levar pra todo lugar gosto bastante comprando outra agora pq sei boa
# Com stemming: dei pro irm caix ótim val bem ver stil som alt dá pra lev pra tod lug gost bast compr outr agor pq sei boa
# Pipeline SVM: dei pro irm caix ótim val bem ver stil som alt dá pra lev pra tod lug gost bast compr outr agor pq sei boa

# %% [markdown]
# ### 2.1 Lematização (demonstrativo)
# Mais lenta que stemming — usada apenas para referência.

# %%
exemplo = exemplos.iloc[0][TEXT_COLUMN]
texto_limpo = remover_stopwords(limpar_texto(exemplo))
print(f"Stemming:     {aplicar_stemming(texto_limpo)[:200]}")
print(f"Lematização:  {aplicar_lematizacao(texto_limpo)[:200]}")
# Out:
# Stemming:     font minuscul dá ler use telescópi esperdic dinh
# Lematização:  fonte minuscular dar ler usar telescópio esperdicei dinheiro

# %% [markdown]
# ## 3. Aplicação ao Dataset Completo
#
# Criamos duas colunas preprocessadas:
# - `texto_svm`: para TF-IDF + SVM (com stemming)
# - `texto_emb`: para embeddings (sem stemming)

# %%
def preprocessar_split(df: pd.DataFrame, nome: str) -> pd.DataFrame:
    """Aplica preprocessamento a um split."""
    print(f"Preprocessando {nome} ({len(df):,} amostras)...")
    with timer(f"Pipeline SVM — {nome}"):
        df["texto_svm"] = df[TEXT_COLUMN].progress_apply(preprocessar_para_svm)
    with timer(f"Pipeline Embeddings — {nome}"):
        df["texto_emb"] = df[TEXT_COLUMN].progress_apply(preprocessar_para_embeddings)
    return df

# %%
df_train = preprocessar_split(df_train, "treino")
df_val = preprocessar_split(df_val, "validação")
df_test = preprocessar_split(df_test, "teste")
# Out:
# Preprocessando treino (90,368 amostras)...
#   0%|          | 0/90368 [00:00<?, ?it/s]
# ⏱ Pipeline SVM — treino: 27.9s
#   0%|          | 0/90368 [00:00<?, ?it/s]
# ⏱ Pipeline Embeddings — treino: 2.2s
# Preprocessando validação (19,365 amostras)...
#   0%|          | 0/19365 [00:00<?, ?it/s]
# ⏱ Pipeline SVM — validação: 5.9s
#   0%|          | 0/19365 [00:00<?, ?it/s]
# ⏱ Pipeline Embeddings — validação: 0.5s
# Preprocessando teste (19,365 amostras)...
#   0%|          | 0/19365 [00:00<?, ?it/s]
# ⏱ Pipeline SVM — teste: 6.0s
#   0%|          | 0/19365 [00:00<?, ?it/s]
# ⏱ Pipeline Embeddings — teste: 0.5s

# %%
# Verificar resultados
print("\nExemplos preprocessados:")
df_train[[TEXT_COLUMN, "texto_svm", "texto_emb", "sentimento"]].head(5)
# Out:
# Exemplos preprocessados:
#                                          review_text  \
# 0  Gostei muito dos produtos, guarda roupa grande...
# 1  A propaganda informava alcance de ate 250mts. ...
# 2  Eu amei , era exatamente o que eu esperava ,  ...
# 3  um pouco mais frágil do que parece na foto, ve...
# 4  Tablet trava o tempo inteiro, não aceita insta...
#
#                                            texto_svm  \
# 0  gost produt guard roup grand espaç comod grand...
# 1  propagand inform alcanc ate mt por nao cheg at...
# 2                          ame exat esper gost recom
# 3  pouc frágil parec fot vei falt um parafus mont...
# 4  tablet tr temp int aceit instal jog registr vá...
#
#                                            texto_emb sentimento
# 0  gostei produtos guarda roupa grande espaçoso c...   positivo
# 1  propaganda informava alcance ate mts porem nao...   negativo
# 2          amei exatamente esperava gostei recomendo   positivo
# 3  pouco frágil parece foto veio faltando uns par...   negativo
# 4  tablet trava tempo inteiro aceita instalação j...   negativo

# %% [markdown]
# ## 4. Salvar Splits Preprocessados

# %%
df_train.to_parquet(PROCESSED_DIR / "train.parquet", index=False)
df_val.to_parquet(PROCESSED_DIR / "val.parquet", index=False)
df_test.to_parquet(PROCESSED_DIR / "test.parquet", index=False)
print("Splits preprocessados salvos com sucesso!")
# Out:
# Splits preprocessados salvos com sucesso!

# %% [markdown]
# ## Resumo
#
# - Pipeline de limpeza aplicada: lowercase, remoção de URLs/números/pontuação
# - Stopwords PT removidas (NLTK)
# - Stemming RSLP aplicado para SVM
# - Colunas `texto_svm` e `texto_emb` criadas nos splits
# - Splits atualizados em `data/processed/`
# - Próximo passo: **03_svm_bow.ipynb**
